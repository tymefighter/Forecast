# %%
from ts.data.dataset import *

# %% [markdown]
# # Amazon Stock Price

# %%
df = AmazonStockPrice.loadData('/Users/ahmed/Downloads/Datasets/amazonStockPrice')
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    1997-05-15     2.437500     2.500000     1.927083     1.958333
# 1    1997-05-16     1.968750     1.979167     1.708333     1.729167
# 2    1997-05-19     1.760417     1.770833     1.625000     1.708333
# 3    1997-05-20     1.729167     1.750000     1.635417     1.635417
# 4    1997-05-21     1.635417     1.645833     1.375000     1.427083
# ...         ...          ...          ...          ...          ...
# 5837 2020-07-27  3062.000000  3098.000000  3015.770020  3055.209961
# 5838 2020-07-28  3054.270020  3077.090088  2995.760010  3000.330078
# 5839 2020-07-29  3030.989990  3039.159912  2996.770020  3033.530029
# 5840 2020-07-30  3014.000000  3092.000000  3005.000000  3051.879883
# 5841 2020-07-31  3244.000000  3246.820068  3151.000000  3164.679932
#
#         Adj Close    Volume
# 0        1.958333  72156000
# 1        1.729167  14700000
# 2        1.708333   6106800
# 3        1.635417   5467200
# ...

# %% [markdown]
# # Retail Sales

# %%
df = RetailSales.loadData('/Users/ahmed/Downloads/Datasets/RetailSales')
df
# Out:
#           date  sale  stock  price
# 0   2014-01-01     0   4972   1.29
# 1   2014-01-02    70   4902   1.29
# 2   2014-01-03    59   4843   1.29
# 3   2014-01-04    93   4750   1.29
# 4   2014-01-05    96   4654   1.29
# ..         ...   ...    ...    ...
# 932 2016-07-27    98   3179   2.39
# 933 2016-07-28   108   3071   2.39
# 934 2016-07-29   128   4095   2.39
# 935 2016-07-30   270   3825   2.39
# 936 2016-07-31   183   3642   2.39
#
# [937 rows x 4 columns]

# %% [markdown]
# # Jaipur Weather

# %%
df = JaipurWeather.loadData('/Users/ahmed/Downloads/Datasets/JaipurWeather')
df
# Out:
#           date  meantempm  maxtempm  mintempm  meantempm_1  meantempm_2  \
# 0   2016-05-04         34        41        27         35.0         36.0
# 1   2016-05-05         31        38        24         34.0         35.0
# 2   2016-05-06         28        34        21         31.0         34.0
# 3   2016-05-07         30        38        23         28.0         31.0
# 4   2016-05-08         34        41        26         30.0         28.0
# ..         ...        ...       ...       ...          ...          ...
# 671 2018-03-07         24        32        15         22.0         23.0
# 672 2018-03-08         24        32        15         24.0         22.0
# 673 2018-03-09         26        33        19         24.0         24.0
# 674 2018-03-10         26        34        19         26.0         24.0
# 675 2018-03-11         26        34        18         26.0         26.0
#
#      meantempm_3  meandewptm_1  meandewptm_2  meandewptm_3  ...  mindewptm_3  \
# ...

# %% [markdown]
# # Indian Subdivision Rainfall

# %%
df = IndianSubdivisionRainfall.loadData(
    '/Users/ahmed/Programming/Project/'
    + 'Forecast/datasets/IndianSubdivisionRainfall.csv'
)
df
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY  \
# 0     Andaman & Nicobar Islands  1901  49.2   87.1   29.2    2.3  528.8
# 1     Andaman & Nicobar Islands  1902   0.0  159.8   12.2    0.0  446.1
# 2     Andaman & Nicobar Islands  1903  12.7  144.0    0.0    1.0  235.1
# 3     Andaman & Nicobar Islands  1904   9.4   14.7    0.0  202.4  304.5
# 4     Andaman & Nicobar Islands  1905   1.3    0.0    3.3   26.9  279.5
# ...                         ...   ...   ...    ...    ...    ...    ...
# 4183                Lakshadweep  2013  26.2   34.4   37.5    5.3   88.3
# 4184                Lakshadweep  2014  53.2   16.1    4.4   14.9   57.4
# 4185                Lakshadweep  2015   2.2    0.5    3.7   87.1  133.1
# 4186                Lakshadweep  2016  59.6   12.1    3.2    2.6   77.4
# 4187                Lakshadweep  2017  21.3    0.9  100.2    1.8  145.7
#
#         JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL     JF    MAM  \
# ...

# %%
df.loc[df['SUBDIVISION'] == 'Kerala']
# Out:
#      SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL    AUG  \
# 3955      Kerala  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0  357.5
# 3956      Kerala  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0  315.8
# 3957      Kerala  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5  420.2
# 3958      Kerala  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5  351.8
# 3959      Kerala  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5  293.6
# ...          ...   ...   ...   ...   ...    ...    ...     ...     ...    ...
# 4067      Kerala  2013   3.9  40.1  49.9   49.3  119.3  1042.7   830.2  369.7
# 4068      Kerala  2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8  733.9
# 4069      Kerala  2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0  252.2
# 4070      Kerala  2016   3.0  16.4  22.4   33.3  258.4   595.7   441.5  231.0
# 4071      Kerala  2017  12.7   0.3  87.8   52.8  213.3   579.8   378.5  462.6
#
# ...

# %% [markdown]
# # Nifty-Fifty Stock

# %%
niftyFiftyStock = NiftyFiftyStock('/Users/ahmed/Downloads/Datasets/NiftyFiftyStock')
print(niftyFiftyStock.getFileNames())
# Out:
# ['BHARTIARTL.csv', 'TATASTEEL.csv', 'TITAN.csv', 'BRITANNIA.csv', 'MM.csv', 'COALINDIA.csv', 'JSWSTEEL.csv', 'NESTLEIND.csv', 'ICICIBANK.csv', 'MARUTI.csv', 'ULTRACEMCO.csv', 'WIPRO.csv', 'NIFTY50_all.csv', 'NTPC.csv', 'VEDL.csv', 'ASIANPAINT.csv', 'ONGC.csv', 'IOC.csv', 'DRREDDY.csv', 'TECHM.csv', 'TCS.csv', 'SUNPHARMA.csv', 'HCLTECH.csv', 'HDFC.csv', 'KOTAKBANK.csv', 'ZEEL.csv', 'AXISBANK.csv', 'EICHERMOT.csv', 'HDFCBANK.csv', 'INFRATEL.csv', 'TATAMOTORS.csv', 'HEROMOTOCO.csv', 'UPL.csv', 'stock_metadata.csv', 'CIPLA.csv', 'BAJAJ-AUTO.csv', 'ITC.csv', 'GAIL.csv', 'POWERGRID.csv', 'HINDALCO.csv', 'BPCL.csv', 'LT.csv', 'ADANIPORTS.csv', 'HINDUNILVR.csv', 'GRASIM.csv', 'RELIANCE.csv', 'INFY.csv', 'SHREECEM.csv', 'SBIN.csv', 'INDUSINDBK.csv', 'BAJAJFINSV.csv', 'BAJFINANCE.csv']

# %%
df = niftyFiftyStock.loadFile('BHARTIARTL.csv')
df
# Out:
#             Date      Symbol Series  Prev Close    Open    High     Low  \
# 0     2002-02-18      BHARTI     EQ        0.00   51.90   51.90   43.50
# 1     2002-02-19      BHARTI     EQ       44.35   45.15   45.15   41.30
# 2     2002-02-20      BHARTI     EQ       41.70   40.60   42.80   40.25
# 3     2002-02-21      BHARTI     EQ       41.25   42.85   43.40   42.15
# 4     2002-02-22      BHARTI     EQ       42.40   42.65   43.60   41.10
# ...          ...         ...    ...         ...     ...     ...     ...
# 4667  2020-11-23  BHARTIARTL     EQ      483.70  486.75  486.75  475.10
# 4668  2020-11-24  BHARTIARTL     EQ      477.25  478.40  481.25  471.20
# 4669  2020-11-25  BHARTIARTL     EQ      474.25  476.50  477.90  458.65
# 4670  2020-11-26  BHARTIARTL     EQ      464.10  468.70  469.65  460.10
# 4671  2020-11-27  BHARTIARTL     EQ      468.40  468.30  472.65  462.00
#
#         Last   Close    VWAP    Volume      Turnover    Trades  \
# ...
