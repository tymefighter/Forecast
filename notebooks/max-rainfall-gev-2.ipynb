# %% [markdown]
# # Studying Maximum Rainfall

# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from pprint import pprint

from ts.utility import Utility
from ts.experimental import GeneralizedExtremeValueDistribution, GevEstimate, Pso
from ts.decompose import StlDecompose

# %% [markdown]
# ## Load Dataset

# %%
rainfall_df = pd.read_csv('../datasets/rainfall-data.csv')[['YEAR', 'MN', 'DT', '..R/F']]
rainfall_df
# Out:
#        YEAR  MN  DT  ..R/F
# 0      1970   1   1    0.0
# 1      1970   1   2    3.2
# 2      1970   1   3    0.0
# 3      1970   1   4    0.0
# 4      1970   1   5    0.0
# ...     ...  ..  ..    ...
# 17647  2018   4  26    0.0
# 17648  2018   4  27    2.1
# 17649  2018   4  28    0.0
# 17650  2018   4  29    0.0
# 17651  2018   4  30    0.0
#
# [17652 rows x 4 columns]

# %% [markdown]
# ## Plot Entire Data

# %%
_ = plt.plot(rainfall_df['..R/F'].to_numpy())

# %% [markdown]
# ## Helper Functions

# %%
def get_most_likely_point(shape, location, scale, low, high, num_particles, num_iter):
    
    def min_func(x):
        
        log_lkhd = GeneralizedExtremeValueDistribution\
            .logLikelihood(shape, location, scale, np.array([x]))
        
        return -log_lkhd if log_lkhd is not None else np.inf
    
    init_pos = Pso.computeInitialPos([(low, high)], num_particles)
    
    return Pso.pso(min_func, init_pos, numIterations=num_iter)

# %%
def get_return_level(shape, location, scale, prob):
    
    if shape == 0:
        return location - scale * np.log(-np.log(1 - prob))
        
    return location - (scale / shape) * (1 - ((-np.log(1 - prob)) ** (-shape)))

# %% [markdown]
# # Fitting GEV to Monthly Maximum

# %% [markdown]
# ## Computing monthly maximum

# %%
month_max_series = [rainfall_df.iloc[0]['..R/F']]
prev_month = rainfall_df.iloc[0]['MN']

for _, row in rainfall_df.iloc[1:].iterrows():
    
    if row['MN'] == prev_month:
        month_max_series[-1] = max(month_max_series[-1], row['..R/F'])
        
    else:
        month_max_series.append(row['..R/F'])
        
    prev_month = row['MN']
    
month_max_series = np.array(month_max_series)

print(f'Data Type: {month_max_series.dtype}, Data Shape: {month_max_series.shape}\n')
print('First 10 data points:')
pprint(list(month_max_series[:10]))
print('')

print('Last 10 data points:')
pprint(list(month_max_series[-10:]))

plt.plot(month_max_series)
plt.title('Monthly Maximum Data')
plt.xlabel('Months')
plt.ylabel('Rainfall Amount')
plt.show()
# Out:
# Data Type: float64, Data Shape: (580,)
#
# First 10 data points:
# [3.2, 45.0, 0.0, 47.0, 25.2, 63.6, 39.0, 57.0, 27.0, 30.0]
#
# Last 10 data points:
# [58.0, 54.2, 88.2, 41.1, 15.2, 24.8, 0.0, 12.6, 14.8, 16.2]

# %% [markdown]
# ## 1) Fitting GEV to monthly data using ML estimation (PSO)

# %% [markdown]
# ### Fit GEV params using PSO on data

# %%
params, max_log_likelihood, max_log_likelihood_vals = GevEstimate.psoMethod(
    month_max_series,
    Pso.computeInitialPos([(-10, 10), (0, 100), (1, 10)], 200),
    numIterations=200
)

shape, location, scale = params
print(f'Shape Parameter: {shape} \n'
    + f'Location Parameter: {location} \n'
    + f'Scale Parameter: {scale} \n'
    + f'Log Likelihood: {max_log_likelihood}')

plt.plot(max_log_likelihood_vals)
plt.title('Convergence Plot')
plt.xlabel('Num. Iterations')
plt.ylabel('Log Likelihood Values')
plt.show()
# Out:
# Shape Parameter: 1.1356359395181657
# Location Parameter: 7.4863995425338015
# Scale Parameter: 12.032791280238264
# Log Likelihood: -2689.128555090656

# %% [markdown]
# ### Plot PDF and CDF

# %%
x = np.linspace(-5, 100, 10000)

plt.plot(
    x, GeneralizedExtremeValueDistribution(
        params[0], params[1], params[2]
    ).pdf(x)
)
plt.title('PDF')
plt.show()

plt.plot(
    x, GeneralizedExtremeValueDistribution(
        params[0], params[1], params[2]
    ).cdf(x)
)
plt.title('CDF')
plt.show()
# Out:
# /Users/ahmed/Programming/Project/Forecast/ts/experimental/genextreme.py:79: RuntimeWarning: invalid value encountered in power
#   / self.scaleParam
# /Users/ahmed/Programming/Project/Forecast/ts/experimental/genextreme.py:95: RuntimeWarning: invalid value encountered in power
#   return np.exp(- ((1 + self.shapeParam * transformData) ** (-1. / self.shapeParam)))

# %% [markdown]
# ### Compute Return Levels for Input Probabilities
#
# Given p, compute the value z such that probability for exceeding
# z in the next month is p. z is called the p - return level for a
# particular p.

# %%
prob = float(input('Enter Probability p: '))
print('Return Level for p = %0.3f is %0.3f'
      %(prob, get_return_level(shape, location, scale, prob)))
# Out:
# Enter Probability p: 0.5
# Return Level for p = 0.500 is 12.956

# %% [markdown]
# ### Get the point with the highest probability density

# %%
most_likely_point, min_neg_log_lkhd, lkhd_vals \
    = get_most_likely_point(shape, location, scale, 20, 300, 200, 100)

plt.plot(lkhd_vals)
plt.title('Negative Log Likelihood Convergence Plot')
plt.show()

print(f'Point with the highest density: {most_likely_point[0]}\n'
    + f'Negative Log Likelihood of this point: {min_neg_log_lkhd}')
# Out:
# Point with the highest density: 1.3669046093829136
# Negative Log Likelihood of this point: 3.0028268054133322

# %% [markdown]
# ## 2) Fitting GEV to trend and seasonality removed data

# %% [markdown]
# ### Decompose the time series into trend, seasonality and remainder components

# %%
trend_series, seasonality_series, remainder_series = StlDecompose\
    .decompose(np.expand_dims(month_max_series, axis=1), 
        period=12, seasonal=501, robust=True)

# %% [markdown]
# ### Plot trend, seasonality and remainder components

# %%
plt.plot(trend_series)
plt.title('Trend Series')
plt.show()

plt.plot(seasonality_series)
plt.title('Seasonality Series')
plt.show()

plt.plot(remainder_series)
plt.title('Remainder Series')
plt.show()

# %% [markdown]
# ### Compare the inferred seasonality with actual data

# %%
# Front Few Points
num_initial_points = 80

plt.plot(seasonality_series[:num_initial_points], label='Inferred Seasonality')
plt.plot(month_max_series[:num_initial_points], label='Actual Data')
plt.legend()
plt.title('Inferred Seasonality and Actual Data - Initial Few Points')
plt.xticks(np.arange(1, num_initial_points, 12))
plt.show()

# Last Few Points
num_last_points = 80

plt.plot(seasonality_series[-num_last_points:], label='Inferred Seasonality')
plt.plot(month_max_series[-num_last_points:], label='Actual Data')
plt.legend()
plt.title('Inferred Seasonality and Actual Data - Last Few Points')
plt.xticks(np.arange(1, num_last_points, 12))
plt.show()

# %% [markdown]
# ### Fitting GEV parameters using PSO to remainder series

# %%
params, max_log_likelihood, max_log_likelihood_vals = GevEstimate.psoMethod(
    remainder_series,
    Pso.computeInitialPos([(-10, 10), (-10, 10), (5, 30)], 200),
    numIterations=200
)

shape, location, scale = params
print(f'Shape Parameter: {shape} \n'
    + f'Location Parameter: {location} \n'
    + f'Scale Parameter: {scale} \n'
    + f'Log Likelihood: {max_log_likelihood}')

plt.plot(max_log_likelihood_vals)
plt.title('Convergence Plot')
plt.xlabel('Num. Iterations')
plt.ylabel('Log Likelihood Values')
plt.show()
# Out:
# Shape Parameter: -0.01015777589264677
# Location Parameter: -6.516376388666546
# Scale Parameter: 20.967652526156684
# Log Likelihood: -2664.9210135948256

# %% [markdown]
# ### Plot PDF and CDF

# %%
x = np.linspace(-100, 100, 10000)

plt.plot(
    x, GeneralizedExtremeValueDistribution(
        params[0], params[1], params[2]
    ).pdf(x)
)
plt.title('PDF')
plt.show()

plt.plot(
    x, GeneralizedExtremeValueDistribution(
        params[0], params[1], params[2]
    ).cdf(x)
)
plt.title('CDF')
plt.show()

# %% [markdown]
# ### Compute Return Levels for Input Probabilities
#
# Given p, compute the value z such that probability for exceeding z in the next month is p. z is called the p - return level for a particular p

# %%
prob = float(input('Enter Probability p: '))
print('Return Level for p = %0.3f is %0.3f'
      %(prob, get_return_level(shape, location, scale, prob)))
# Out:
# Enter Probability p: 0.5
# Return Level for p = 0.500 is 1.154

# %% [markdown]
# ### Get the point with the highest probability density

# %%
most_likely_point, min_neg_log_lkhd, lkhd_vals \
    = get_most_likely_point(shape, location, scale, 20, 300, 200, 100)

plt.plot(lkhd_vals)
plt.title('Negative Log Likelihood Convergence Plot')
plt.show()

print(f'Point with the highest density: {most_likely_point[0]}\n'
    + f'Negative Log Likelihood of this point: {min_neg_log_lkhd}')
# Out:
# Point with the highest density: -6.302313885960149
# Negative Log Likelihood of this point: 4.0429291284795505

# %% [markdown]
# ### Compute CDF of each data point in remainder series

# %%
remainder_series_cdf = GeneralizedExtremeValueDistribution(*tuple(params))\
    .cdf(remainder_series)

print(f'Data Type: {remainder_series_cdf.dtype}, Data Shape: {remainder_series_cdf.shape}\n')
print('First 5 data points:')
pprint(remainder_series_cdf[:5])
print('')

print('Last 5 data points:')
pprint(remainder_series_cdf[-5:])

plt.plot(remainder_series_cdf)
plt.title('Monthly Maximum Data')
plt.xlabel('Months')
plt.ylabel('Rainfall Amount')
plt.show()
# Out:
# Data Type: float64, Data Shape: (580, 1)
#
# First 5 data points:
# array([[0.25056518],
#        [0.83097955],
#        [0.17028366],
#        [0.47335147],
#        [0.18597643]])
#
# Last 5 data points:
# array([[0.69196533],
#        [0.37379224],
#        [0.54140138],
#        [0.46913592],
#        [0.43599189]])

# %% [markdown]
# ## Build Model for Forecasting next day CDF

# %% [markdown]
# ### LSTM

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense, TimeDistributed

model = Sequential([
    LSTM(units=16, return_sequences=True, activation='relu'),
    LSTM(units=32, return_sequences=True, activation='relu'),
    LSTM(units=64, return_sequences=True, activation='relu'),
    LSTM(units=32, return_sequences=True, activation='relu'),
    LSTM(units=16, return_sequences=True, activation='relu'),
    TimeDistributed(Dense(units=1, activation=None))
])

model.build(input_shape=(None, None, 1))
model.compile(
    optimizer=tf.optimizers.Adam(1e-3),
    loss=tf.losses.MeanSquaredError()
)

# %%
input_data = np.expand_dims(remainder_series[:-1], axis=0)
output_data = np.expand_dims(remainder_series_cdf[1:], axis=0)

print(f'Input Data Shape: {input_data.shape}')
print(f'Output Data Shape: {output_data.shape}')
# Out:
# Input Data Shape: (1, 579, 1)
# Output Data Shape: (1, 579, 1)

# %%
model.fit(input_data, output_data, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 912us/step - loss: 0.3040
# Epoch 2/10
# 1/1 [==============================] - 0s 826us/step - loss: 0.2677
# Epoch 3/10
# 1/1 [==============================] - 0s 846us/step - loss: 0.2371
# Epoch 4/10
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2044
# Epoch 5/10
# 1/1 [==============================] - 0s 845us/step - loss: 0.1698
# Epoch 6/10
# 1/1 [==============================] - 0s 847us/step - loss: 0.1362
# Epoch 7/10
# 1/1 [==============================] - 0s 847us/step - loss: 0.1265
# Epoch 8/10
# 1/1 [==============================] - 0s 890us/step - loss: 0.1333
# Epoch 9/10
# 1/1 [==============================] - 0s 851us/step - loss: 0.1119
# Epoch 10/10
# 1/1 [==============================] - 0s 842us/step - loss: 0.0995

# %%
plt.plot(np.squeeze(output_data))
plt.plot(np.squeeze(model.predict(input_data)))

# %% [markdown]
# ### DNN

# %%
lag = 50

model = Sequential([
    Dense(16, activation='relu'),
    Dense(32, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.build(input_shape=(None, lag))
model.compile(
    optimizer=tf.optimizers.Adam(
        tf.optimizers.schedules.ExponentialDecay(
            0.01, 50, 0.9
        )
    ),
    loss=tf.losses.MeanSquaredError()
)

# %%
input_data = []
output_data = []

for i in range(lag + 1, remainder_series.shape[0]):
    input_data.append(np.squeeze(remainder_series_cdf[i - lag:i], axis=1))
    output_data.append(remainder_series_cdf[i])
    
input_data = np.array(input_data)
output_data = np.array(output_data)
    
print(f'Input Data Shape: {input_data.shape}')
print(f'Output Data Shape: {output_data.shape}')
# Out:
# Input Data Shape: (529, 50)
# Output Data Shape: (529, 1)

# %%
history = model.fit(input_data, output_data, epochs=100)
plt.plot(history.history['loss'])
# Out:
# Epoch 1/100
# 17/17 [==============================] - 0s 907us/step - loss: 0.0696
# Epoch 2/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0686
# Epoch 3/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0659
# Epoch 4/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0638
# Epoch 5/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0616
# Epoch 6/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0622
# Epoch 7/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0579
# Epoch 8/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0629
# Epoch 9/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0589
# Epoch 10/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0558
# Epoch 11/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0551
# Epoch 12/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0521
# Epoch 13/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0538
# Epoch 14/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0514
# Epoch 15/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0545
# Epoch 16/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0559
# Epoch 17/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0500
# Epoch 18/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0497
# Epoch 19/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0483
# Epoch 20/100
# 17/17 [==============================] - 0s 983us/step - loss: 0.0482
# Epoch 21/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0491
# Epoch 22/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0493
# Epoch 23/100
# 17/17 [==============================] - 0s 988us/step - loss: 0.0472
# Epoch 24/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0478
# Epoch 25/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0458
# Epoch 26/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0454
# Epoch 27/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0456
# Epoch 28/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0429
# Epoch 29/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0450
# Epoch 30/100
# 17/17 [==============================] - 0s 967us/step - loss: 0.0481
# Epoch 31/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0466
# Epoch 32/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0447
# Epoch 33/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0452
# Epoch 34/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0437
# Epoch 35/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0438
# Epoch 36/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0434
# Epoch 37/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0417
# Epoch 38/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0408
# Epoch 39/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0401
# Epoch 40/100
# 17/17 [==============================] - 0s 961us/step - loss: 0.0397
# Epoch 41/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0389
# Epoch 42/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0387
# Epoch 43/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0381
# Epoch 44/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0384
# Epoch 45/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0377
# Epoch 46/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0367
# Epoch 47/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0368
# Epoch 48/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0369
# Epoch 49/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0361
# Epoch 50/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0362
# Epoch 51/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0360
# Epoch 52/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0352
# Epoch 53/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0344
# Epoch 54/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0341
# Epoch 55/100
# 17/17 [==============================] - 0s 976us/step - loss: 0.0344
# Epoch 56/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0348
# Epoch 57/100
# 17/17 [==============================] - 0s 964us/step - loss: 0.0338
# Epoch 58/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0333
# Epoch 59/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0332
# Epoch 60/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0331
# Epoch 61/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0332
# Epoch 62/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0328
# Epoch 63/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0333
# Epoch 64/100
# 17/17 [==============================] - 0s 981us/step - loss: 0.0325
# Epoch 65/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0322
# Epoch 66/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0318
# Epoch 67/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0314
# Epoch 68/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0315
# Epoch 69/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0314
# Epoch 70/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0311
# Epoch 71/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0308
# Epoch 72/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0306
# Epoch 73/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0301
# Epoch 74/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0305
# Epoch 75/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0301
# Epoch 76/100
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0298
# Epoch 77/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0296
# Epoch 78/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0295
# Epoch 79/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0293
# Epoch 80/100
# 17/17 [==============================] - 0s 998us/step - loss: 0.0291
# Epoch 81/100
# 17/17 [==============================] - 0s 943us/step - loss: 0.0289
# Epoch 82/100
# 17/17 [==============================] - 0s 974us/step - loss: 0.0289
# Epoch 83/100
# 17/17 [==============================] - 0s 998us/step - loss: 0.0288
# Epoch 84/100
# 17/17 [==============================] - 0s 898us/step - loss: 0.0287
# Epoch 85/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0287
# Epoch 86/100
# 17/17 [==============================] - 0s 955us/step - loss: 0.0285
# Epoch 87/100
# 17/17 [==============================] - 0s 955us/step - loss: 0.0285
# Epoch 88/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0283
# Epoch 89/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0284
# Epoch 90/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0282
# Epoch 91/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0281
# Epoch 92/100
# 17/17 [==============================] - 0s 953us/step - loss: 0.0279
# Epoch 93/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0279
# Epoch 94/100
# 17/17 [==============================] - 0s 989us/step - loss: 0.0279
# Epoch 95/100
# 17/17 [==============================] - 0s 915us/step - loss: 0.0278
# Epoch 96/100
# 17/17 [==============================] - 0s 971us/step - loss: 0.0277
# Epoch 97/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0277
# Epoch 98/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0275
# Epoch 99/100
# 17/17 [==============================] - 0s 1ms/step - loss: 0.0275
# Epoch 100/100
# 17/17 [==============================] - 0s 997us/step - loss: 0.0275

# %%
plt.plot(np.squeeze(output_data))
plt.plot(np.squeeze(model.predict(input_data)))

# %% [markdown]
# ## Time Pass !!!

# %%
pred = GeneralizedExtremeValueDistribution(*tuple(params)) \
    .computeQuantile(model.predict(input_data))

pred = np.maximum(pred + trend_series[lag + 1:] + seasonality_series[lag + 1:], 0)
true = month_max_series[lag + 1:]

# %%
plt.plot(true, label='true')
plt.plot(pred, label='pred')
plt.show()

# %%
plt.plot(true[400:], label='true')
plt.plot(pred[400:], label='pred')
plt.show()
